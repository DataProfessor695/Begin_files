# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Install libraries
# ```python
# pip install pandas
# pip install seaborn
# pip install numpy
# ```

# %%
# import libraries 
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
kashti = sns.load_dataset('titanic')
ks1 = kashti 
ks2 = kashti
ks = sns.load_dataset('titanic')

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# simple operation (Math operator)
(kashti['age']+2).head(8)
# Out:
# 0    24.0
# 1    40.0
# 2    28.0
# 3    37.0
# 4    37.0
# 5     NaN
# 6    56.0
# 7     4.0
# Name: age, dtype: float64

# %% [markdown]
# ## Dealing with missing values
# - In a Data set missing values are either? or N/A or _NaN_, or 0 or a blank cell.
# - Jab kabhi data na ho kisi aik row main kisi b aik paramter ka
# > Steps:
# 1. Koshish karen dobara data collect kar len ya dekh len agar kahin ghalti hai.
# 2. Missing value wala variable (column) hi nikal den agar data per effect nahi hta ya \
#    row or data entry remove kar den.
# 3. Replace the missing values:
#      1. How?
#            1. Average value of entire variable or similar data point
#            2. Frequency or MODE replacement
#            3. Replace based on other function (Data sampler knows that)
#            4. ML(machine learning) algorithm can also be used
#            5. Leave it like that
#      2. Why?
#         1. Its better because no data is lost
#         2. Less Accurate

# %%
# Where exactly missing values are? 
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Use dron.na method 
print (kashti.shape)
kashti.dropna(subset=['deck'],axis=0 ,inplace=True) # this will remove
# Inplace = true modifies the data frame(change in original data_set)
# Out:
# (891, 15)

# %%
kashti.isnull().sum() # Find again null value
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
# To drop na
kashti = kashti.dropna()
# to update the main dataframe
kashti.isnull().sum() # remove na form whole dataframe
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti.shape
# Out:
# (182, 15)

# %%
ks1.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %% [markdown]
# ## Replacing Missing values with the average of that column.

# %%
# finding an average (mean)
mean= ks1['age'].mean()
mean
# Out:
# 35.77945652173913

# %%
# replacing NaN with mean of the data (updating as well)
ks1['age']= ks1['age'].replace(np.nan,mean)

# %%
ks1.isnull().sum() # replace the age
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# ### Removing/Replacing 'deck' As Assignment

# %%
# mean1=ks1['deck'].mean()
# mean1

# %%
# ks1['deck'] = ks1['deck'].replace(np.NaN,)

# %% [markdown]
# ## Data Formatting
# - Data ko aik common standard par lana.
# - Ensures data is consitent and understandable
#     - Easy to gather
#     - Easy to workwith
#         - Faisalabad(FSD)
#         - Lahore(LHR)
#         - Islamabad(ISB)
#         - Karachi(KCH)
#         - Peshawar(PEW)
#         - Jaisy chilly main log apni kartay hamesha
#         - Convert g to kg or similar uni for all
#         - one standard unit in each column
#         - ft != cm

# %%
# know the data type and convert it into the known one 
ks1.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# use this method to convert datatype from one to another format 
kashti['survived'] = kashti['survived'].astype('float64')
kashti.dtypes
# Out:
# C:\Users\Muhammad Mudassir\AppData\Local\Temp\ipykernel_5564\711776432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kashti['survived'] = kashti['survived'].astype('float64')
# survived        float64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# Here we will convert the age into days instead of years
ks1['age']=ks1['age']*365
ks1.head()
# Out:
#     survived  pclass     sex      age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  13870.0      1      0  71.2833        C  First
# 3          1       1  female  12775.0      1      0  53.1000        S  First
# 6          0       1    male  19710.0      0      0  51.8625        S  First
# 10         1       3  female   1460.0      1      1  16.7000        S  Third
# 11         1       1  female  21170.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 6     man        True    E  Southampton    no   True
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True

# %%
# Always Rename Afterwards
ks1.rename(columns={'age':'age in days'},inplace=True)
ks1.head()
# Out:
#    survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 0         0       3    male         22.0      1      0   7.2500        S
# 1         1       1  female         38.0      1      0  71.2833        C
# 2         1       3  female         26.0      0      0   7.9250        S
# 3         1       1  female         35.0      1      0  53.1000        S
# 4         0       3    male         35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## **Data Normalization**
# - Uniform the data
# - They have same impact
# - Aik machli samundar main or aik jar main
# - Also for computational reasons

# %%
kashti.head()
# Out:
#    survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 0         0       3    male         22.0      1      0   7.2500        S
# 1         1       1  female         38.0      1      0  71.2833        C
# 2         1       3  female         26.0      0      0   7.9250        S
# 3         1       1  female         35.0      1      0  53.1000        S
# 4         0       3    male         35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
ks4= kashti[['age in days','fare']]
ks4.head()
# Out:
#    age in days     fare
# 0         22.0   7.2500
# 1         38.0  71.2833
# 2         26.0   7.9250
# 3         35.0  53.1000
# 4         35.0   8.0500

# %% [markdown]
# - The above data is really in wide range and we need to normalize and hard to compare.
# - Normalization change the values to the range of 0-to-1 (now both variable has similar influence on our models)
#   ## Method of Normalization
# 1. Simple feature scaling
#     - x(new=x(old)/x(max))
# 2. Min-Max method
# 3. Z-score (standard score)-3-to-+3
# 4. Log transformation

# %%
# simple feature scalling 
ks4['fare']=ks4['fare']/ks4['fare'].max()
ks4['age in days']=ks4['age in days']/ks4['age in days'].max()
ks4.head()
# Out:
# C:\Users\Muhammad Mudassir\AppData\Local\Temp\ipykernel_6520\2134855222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare']=ks4['fare']/ks4['fare'].max()
# C:\Users\Muhammad Mudassir\AppData\Local\Temp\ipykernel_6520\2134855222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['age in days']=ks4['age in days']/ks4['age in days'].max()
#    age in days      fare
# 0       0.2750  0.014151
# 1       0.4750  0.139136
# 2       0.3250  0.015469
# 3       0.4375  0.103644
# 4       0.4375  0.015713

# %%
# Min-Max Method
ks4['fare']=(ks4['fare']-ks4['fare'].min())/(ks4['fare'].max()-ks4['fare'].min())
ks4.head()
# Out:
# C:\Users\Muhammad Mudassir\AppData\Local\Temp\ipykernel_6520\1283291884.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare']=(ks4['fare']-ks4['fare'].min())/(ks4['fare'].max()-ks4['fare'].min())
#    age in days      fare
# 0         22.0  0.014151
# 1         38.0  0.139136
# 2         26.0  0.015469
# 3         35.0  0.103644
# 4         35.0  0.015713

# %%
# Z-score (standard score)
ks4['fare']=(ks4['fare']-ks4['fare'].mean())/ks4['fare'].std()
ks4.head()
# Out:
# C:\Users\Muhammad Mudassir\AppData\Local\Temp\ipykernel_6520\3666210801.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks4['fare']=(ks4['fare']-ks4['fare'].mean())/ks4['fare'].std()
#    age in days      fare
# 0         22.0 -0.502163
# 1         38.0  0.786404
# 2         26.0 -0.488580
# 3         35.0  0.420494
# 4         35.0 -0.486064

# %%
# log transformation
ks['fare']=np.log(ks['fare'])
ks.head()
# Out:
# c:\Users\Muhammad Mudassir\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### **Binning**
# - Grouping of values into smaller number of values (bins)
# - Convert numeric into categories(Jawan,Bachay,Boorhay)or 1-16,17-30 etc
# - To have better understanding of groups
#   - low vs mid vs high price

# %%
bins = np.linspace(min(ks['age']),max(ks['age']),15000)
age_groups = ['Bachay','Jawan','Boorhay']
ks['age']=pd.cut(ks['age'],bins,labels=age_groups,include_lowest=True)
ks['age']
# how this will change the names in dataset based on grouping? (Assignment)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Muhammad Mudassir\Desktop\Jupyter_Notebook\Data_Wrangling.ipynb Cell 35 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Muhammad%20Mudassir/Desktop/Jupyter_Notebook/Data_Wrangling.ipynb#ch0000034?line=0'>1</a> bins = np.linspace(min(ks['age']),max(ks['age']),15000)
#       <a href='vscode-notebook-cell:/c%3A/Users/Muhammad%20Mudassir/Desktop/Jupyter_Notebook/Data_Wrangling.ipynb#ch0000034?line=1'>2</a> age_groups = ['Bachay','Jawan','Boorhay']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Muhammad%20Mudassir/Desktop/Jupyter_Notebook/Data_Wrangling.ipynb#ch0000034?line=2'>3</a> ks['age']=pd.cut(ks['age'],bins,labels=age_groups,include_lowest=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Muhammad%20Mudassir/Desktop/Jupyter_Notebook/Data_Wrangling.ipynb#ch0000034?line=3'>4</a> ks['age']
#
# File c:\Users\Muhammad Mudassir\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\tile.py:292, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     289     if (np.diff(bins.astype("float64")) < 0).any():
#     290         raise ValueError("bins must increase monotonically.")
# --> 292 fac, bins = _bins_to_cuts(
#     293     x,
#     294     bins,
#     295     right=right,
#     296     labels=labels,
#     297     precision=precision,
#     298     include_lowest=include_lowest,
#     299     dtype=dtype,
#     300     duplicates=duplicates,
#     301     ordered=ordered,
#     302 )
#     304 return _postprocess_for_cut(fac, bins, retbins, dtype, original)
#
# File c:\Users\Muhammad Mudassir\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\tile.py:453, in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     451 else:
#     452     if len(labels) != len(bins) - 1:
# --> 453         raise ValueError(
#     454             "Bin labels must be one fewer than the number of bin edges"
#     455         )
#     456 if not is_categorical_dtype(labels):
#     457     labels = Categorical(
#     458         labels,
#     459         categories=labels if len(set(labels)) == len(labels) else None,
#     460         ordered=ordered,
#     461     )
#
# ValueError: Bin labels must be one fewer than the number of bin edges

# %% [markdown]
# ### **Converting categories into dumies**
# - easy to use for computation
# - Male Female (0,1)

# %%
pd.get_dummies(kashti['sex'])
# how to use get dumies to change data inside a dataframe (Assignment)
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
kashti=pd.get_dummies(kashti, columns=['sex'])

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
kashti.tail()
# Out:
#      female  male
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
