# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
t= sns.load_dataset('titanic')
t.to_csv('titanic.csv')

# %%
kashti=pd.read_csv('Titanic.csv')
kashti.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
kashti.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   445.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      0.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    222.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    445.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    667.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    890.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
kashti.mean()
# Out:
# C:\Users\Muhammad Mudassir\AppData\Local\Temp\ipykernel_8544\3332994036.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti.mean()
# Unnamed: 0    445.000000
# survived        0.383838
# pclass          2.308642
# age            29.699118
# sibsp           0.523008
# parch           0.381594
# fare           32.204208
# adult_male      0.602694
# alone           0.602694
# dtype: float64

# %%
kashti.groupby(['sex','class']).mean()
# Out:
#                Unnamed: 0  survived  pclass        age     sibsp     parch  \
# sex    class
# female First   468.212766  0.968085     1.0  34.611765  0.553191  0.457447
#        Second  442.105263  0.921053     2.0  28.722973  0.486842  0.605263
#        Third   398.729167  0.500000     3.0  21.750000  0.895833  0.798611
# male   First   454.729508  0.368852     1.0  41.281386  0.311475  0.278689
#        Second  446.962963  0.157407     2.0  30.740707  0.342593  0.222222
#        Third   454.515850  0.135447     3.0  26.507589  0.498559  0.224784
#
#                      fare  adult_male     alone
# sex    class
# female First   106.125798    0.000000  0.361702
#        Second   21.970121    0.000000  0.421053
#        Third    16.118810    0.000000  0.416667
# male   First    67.226127    0.975410  0.614754
#        Second   19.741782    0.916667  0.666667
#        Third    12.661633    0.919308  0.760807

# %%
kashti[kashti['age']< 18].groupby(['sex','class']).mean()
# Out:
#                Unnamed: 0  survived  pclass        age     sibsp     parch  \
# sex    class
# female First   524.375000  0.875000     1.0  14.125000  0.500000  0.875000
#        Second  368.250000  1.000000     2.0   8.333333  0.583333  1.083333
#        Third   373.942857  0.542857     3.0   8.428571  1.571429  1.057143
# male   First   525.500000  1.000000     1.0   8.230000  0.500000  2.000000
#        Second  526.818182  0.818182     2.0   4.757273  0.727273  1.000000
#        Third   436.953488  0.232558     3.0   9.963256  2.069767  1.000000
#
#                      fare  adult_male     alone
# sex    class
# female First   104.083337    0.000000  0.125000
#        Second   26.241667    0.000000  0.166667
#        Third    18.727977    0.000000  0.228571
# male   First   116.072900    0.250000  0.000000
#        Second   25.659473    0.181818  0.181818
#        Third    22.752523    0.348837  0.232558

# %%
kashti.iloc[7:12,0:4]
# Out:
#     Unnamed: 0  survived  pclass     sex
# 7            7         0       3    male
# 8            8         1       3  female
# 9            9         1       2  female
# 10          10         1       3  female
# 11          11         1       1  female

# %%
class23=kashti[(kashti['pclass']==2)|(kashti['pclass']==3)]
class23
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 2             2         1       3  female  26.0      0      0   7.9250
# 4             4         0       3    male  35.0      0      0   8.0500
# 5             5         0       3    male   NaN      0      0   8.4583
# 7             7         0       3    male   2.0      3      1  21.0750
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 884         884         0       3    male  25.0      0      0   7.0500
# 885         885         0       3  female  39.0      0      5  29.1250
# 886         886         0       2    male  27.0      0      0  13.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
class1=kashti[(kashti['pclass']==1)]
class1
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 1             1         1       1  female  38.0      1      0  71.2833
# 3             3         1       1  female  35.0      1      0  53.1000
# 6             6         0       1    male  54.0      0      0  51.8625
# 11           11         1       1  female  58.0      0      0  26.5500
# 23           23         1       1    male  28.0      0      0  35.5000
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 871         871         1       1  female  47.0      1      1  52.5542
# 872         872         0       1    male  33.0      0      0   5.0000
# 879         879         1       1  female  56.0      0      1  83.1583
# 887         887         1       1  female  19.0      0      0  30.0000
# 889         889         1       1    male  26.0      0      0  30.0000
#
#     embarked  class    who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti[['survived','sex']]
# Out:
#      survived     sex
# 0           0    male
# 1           1  female
# 2           1  female
# 3           1  female
# 4           0    male
# ..        ...     ...
# 886         0    male
# 887         1  female
# 888         0  female
# 889         1    male
# 890         0    male
#
# [891 rows x 2 columns]

# %%
kashti['survived'].shape
# Out:
# (891,)

# %%
kashti['age'].max()
# Out:
# 80.0

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          714 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     889 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  adult_male   891 non-null    bool
#  12  deck         203 non-null    object
#  13  embark_town  889 non-null    object
#  14  alive        891 non-null    object
#  15  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(5), object(7)
# memory usage: 99.3+ KB

# %%
kashti['age']>18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
adult_names=kashti.loc[kashti['age']>18,'age']
adult_names
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 575, dtype: float64

# %%
sns.barplot(x='class',y='survived',hue='who',palette='pastel', data=kashti)
plt.show()

# %%
sns.countplot(x='class',data=kashti,hue="who")
plt.show()
